# %% [markdown]
# # 「LSTM単語言語モデルの動的量子化（ベータ版）」
#
# 【原題】(beta) Dynamic Quantization on an LSTM Word Language Model
#
# 【原著】[James Reed](https://github.com/jamesr66a)
#
# 【編著】[Seth Weidman](https://github.com/SethHWeidman/)
#
# 【元URL】https://pytorch.org/tutorials/advanced/dynamic_quantization_tutorial.html
#
# 【翻訳】電通国際情報サービスISID HCM事業部　櫻井 亮佑
#
# 【日付】2020年1月31日
#
# 【チュトーリアル概要】
#
# 本チュートリアルでは、重みの数値を格納するビット数を減らし、モデルサイズの削減、推論速度向上に寄与する量子化を、LSTMベースの次単語予測モデルに適用します

# %% [markdown]
# ## 導入
#
# 量子化では、モデルの重みと活性化をfloatからintに変換します。
#
# 量子化により、精度への影響を最小限に抑えた上でモデルのサイズを小さくし、推論を高速化することができます。
#
# 本チュートリアルでは、PyTorchのサンプル例より、[単語言語モデル](https://github.com/pytorch/examples/tree/master/word_language_model)に対して、LSTMベースの次単語予測モデルに最も簡単な量子化の仕組みである[動的量子化](https://pytorch.org/docs/stable/quantization.html#torch.quantization.quantize_dynamic) を適用します。

# %%
# %matplotlib inline

# %%
# インポート
import os
from io import open
import time

import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ## 1. モデルの定義
#
# 単語言語モデルの例より、こちらの[モデル](https://github.com/pytorch/examples/blob/master/word_language_model/model.py)に従い、LSTMモデルの構造を定義します。

# %%
class LSTMModel(nn.Module):
    """エンコーダー、再帰モジュール、そしてデコーダーを含むモデル構成"""

    def __init__(self, ntoken, ninp, nhid, nlayers, dropout=0.5):
        super(LSTMModel, self).__init__()
        self.drop = nn.Dropout(dropout)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.rnn = nn.LSTM(ninp, nhid, nlayers, dropout=dropout)
        self.decoder = nn.Linear(nhid, ntoken)

        self.init_weights()

        self.nhid = nhid
        self.nlayers = nlayers

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, input, hidden):
        emb = self.drop(self.encoder(input))
        output, hidden = self.rnn(emb, hidden)
        output = self.drop(output)
        decoded = self.decoder(output)
        return decoded, hidden

    def init_hidden(self, bsz):
        weight = next(self.parameters())
        return (weight.new_zeros(self.nlayers, bsz, self.nhid),
                weight.new_zeros(self.nlayers, bsz, self.nhid))

# %% [markdown]
# ## 2. テキストデータの読み込み
#
# 同様に、単語言語モデルの[前処理](https://github.com/pytorch/examples/blob/master/word_language_model/data.py)に従い、[Wikitext-2 データセット](https://www.google.com/search?q=wikitext+2+data)を`Corpus`に読み込みます。

# %%
# 日本語訳版追加　Wikitext-2データセットのダウンロード
import urllib.request
import zipfile

# ダウンロード
for item in ["train.txt", "valid.txt", "test.txt"]:
    url = "https://github.com/pytorch/examples/tree/master/word_language_model/data/wikitext-2/"+item
    save_path = "/content/data/wikitext-2/"+item
    urllib.request.urlretrieve(url, save_path)

# 以下のモデルはこのチュートリアルとは、モデルサイズが異なる・・・
#url ="https://s3.amazonaws.com/pytorch-tutorial-assets/word_language_model_quantize.pth"
#save_path = "/content/data/word_language_model_quantize.pth"
#urllib.request.urlretrieve(url, save_path)
# Out:
# ('/content/data/word_language_model_quantize.pth',
#  <http.client.HTTPMessage at 0x7f9d138c1cf8>)

# %%
class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)


class Corpus(object):
    def __init__(self, path):
        self.dictionary = Dictionary()
        self.train = self.tokenize(os.path.join(path, 'train.txt'))
        self.valid = self.tokenize(os.path.join(path, 'valid.txt'))
        self.test = self.tokenize(os.path.join(path, 'test.txt'))

    def tokenize(self, path):
        """テキストファイルのトークン化"""
        assert os.path.exists(path)
        # 辞書に単語を追加
        with open(path, 'r', encoding="utf8") as f:
            for line in f:
                words = line.split() + ['<eos>']
                for word in words:
                    self.dictionary.add_word(word)

        # ファイルの内容をトークン化
        with open(path, 'r', encoding="utf8") as f:
            idss = []
            for line in f:
                words = line.split() + ['<eos>']
                ids = []
                for word in words:
                    ids.append(self.dictionary.word2idx[word])
                idss.append(torch.tensor(ids).type(torch.int64))
            ids = torch.cat(idss)

        return ids

#model_data_filepath = 'data/'
model_data_filepath = '/content/data/'  # 日本語訳版変更、GoogleClabで実行できるパスに 

corpus = Corpus(model_data_filepath + 'wikitext-2')

# %% [markdown]
# ## 3. 事前訓練済みモデルの読み込み
#
# 本チュートリアルでは動的量子化について扱いますが、量子化のテクニックはモデルの訓練が完了したあとに適用します。
#
# そのため、まずは単に事前訓練済みの重みをモデルの構造に読み込みます。
#
# なお、使用する重みは単語言語モデルの例のデフォルトの設定を使って、5エポックにわたり訓練して求めた値です。

# %%
ntokens = len(corpus.dictionary)

model = LSTMModel(
    ntoken = ntokens,
    ninp = 512,
    nhid = 256,
    nlayers = 5,
)

# 日本語訳版変更　今回は訓練済みデータの読み込みはなしにする。該当ファイルが見つからない・・・
#model.load_state_dict(
#    torch.load(
#        model_data_filepath + 'word_language_model_quantize.pth',
#        map_location=torch.device('cpu')
#        )
#    )

model.eval()
print(model)
# Out:
# LSTMModel(
#   (drop): Dropout(p=0.5, inplace=False)
#   (encoder): Embedding(2363, 512)
#   (rnn): LSTM(512, 256, num_layers=5, dropout=0.5)
#   (decoder): Linear(in_features=256, out_features=2363, bias=True)
# )

# %% [markdown]
# 前と同じように[こちら](https://github.com/pytorch/examples/blob/master/word_language_model/generate.py)を参考にして文章を生成し、訓練済みモデルが適切に動作することを確かめます。

# %%
input_ = torch.randint(ntokens, (1, 1), dtype=torch.long)
hidden = model.init_hidden(1)
temperature = 1.0
num_words = 1000

with open(model_data_filepath + 'out.txt', 'w') as outf:
    with torch.no_grad():  # 勾配のトラッキングを無効化
        for i in range(num_words):
            output, hidden = model(input_, hidden)
            word_weights = output.squeeze().div(temperature).exp().cpu()
            word_idx = torch.multinomial(word_weights, 1)[0]
            input_.fill_(word_idx)

            word = corpus.dictionary.idx2word[word_idx]

            outf.write(str(word.encode('utf-8')) + ('\n' if i % 20 == 19 else ' '))

            if i % 100 == 0:
                print('| Generated {}/{} words'.format(i, 1000))

with open(model_data_filepath + 'out.txt', 'r') as outf:
    all_output = outf.read()
    print(all_output)
# Out:
# | Generated 0/1000 words
# | Generated 100/1000 words
# | Generated 200/1000 words
# | Generated 300/1000 words
# | Generated 400/1000 words
# | Generated 500/1000 words
# | Generated 600/1000 words
# | Generated 700/1000 words
# | Generated 800/1000 words
# | Generated 900/1000 words
# b'&quot;16822470375&quot;,' b'or' b'data-menu-item="i3actions-tab"' b'&quot;control&quot;},' b'class="jump-to-octicon' b'or' b'js-permalink-shortcut"' b'content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA">' b'Open' b'data-src="https://github.githubassets.com/assets/chunk-runner-groups-13e1fec0.js"></script>' b'data-platforms="windows,mac"' b'left-0' b'data-hydro-click-hmac="ef93c2505f3805730378a168ba4cd6a5c4869e59513f8ab970098de8673b7e91"' b'cursor-pointer"' b'class="Bump-link-symbol' b'pt-lg-3">' b'js-jump-to-global-search' b'class="css-truncate' b'starred' b'flex-justify-between'
# b'Box-body' b'd="M1.643' b'd="M11.5' b'css-truncate' b'15H1.918a1.75' b'5.169.88' b'01-.765' b'logged' b'01-1.482-.236A5.507' b'can\xe2\x80\x99t' b'0011' b'data-pjax-replace' b'class="btn-link' b'Watch' b'aria-label="More' b'data-pjax-transient="true"/><meta' b'Go' b'pb-2' b'class="jump-to-suggestion-name' b'&quot;19820830627&quot;,'
# b'&quot;18568612016&quot;,' b'href="#start-of-content"' b'data-menu-item="i3actions-tab"' b'selected' b'd="M7.467.133a1.75' b'7V3.48a1.75' b'{\\&quot;match\\&quot;:' b'002.25-2.25v-.878a2.25' b'8c0-4.42-3.58-8-8-8z"></path></svg>' b'css-truncate"' b'4.682-.983' b'001.5' b'data-tab-item="i3actions-tab"' b'repo_labels' b'class="avatar' b'00-1.06' b'&quot;click.org_onboarding_checklist.add_repo&quot;},' b'flex-items-center"' b'aria-label="Menu' b'0v1.836A2.492'
# b'You' b'class="js-notification-shelf-include-fragment"' b'content="repository,source-code"' b'16h12.5A1.75' b'class="dropdown-caret"></span>' b'100-1.5.75.75' b'octicon-eye"' b'data-hydro-click-hmac="53bcce1944a128cc5109ec7be45e2dc23b470e15f40ef13cf7ec60f360aee987"' b'href="/security"' b'color:' b'1.08.58' b'd="M13.78' b'are' b'</include-fragment>' b'&quot;id&quot;:' b'class="Header-old' b'110-1.5h1.75v-2h-8a1' b'data-hotkey="g' b'name="hovercard-subject-tag"' b'</template>'
# b'a"' b'class="tooltipped' b'checks' b'text-center' b'0C3.58' b'property="og:site_name"' b'&quot;featureFlags&quot;:' b'005.405' b'010-1.06z"></path></svg>' b'id="tags-menu"' b'integrity="sha512-evfy6RyDyXvLuaEEFaUaIlw9dSRgvKkF3rMeUELkvXq7sGEK/43vTg+3EE6E8nOsjpuPyYQjgS8bxzqkTjlZag=="' b'&quot;submit.homepage_signup&quot;},' b'Program">GitHub' b'</head>' b'0115' b'repeatCount="indefinite"' b'pt-2' b'position-absolute' b'0114.082' b'mb-n1">'
# b'octicon-code' b'menu&quot;,&quot;repository_id&quot;:null,&quot;auth_type&quot;:&quot;SIGN_UP&quot;,&quot;originating_url&quot;:&quot;https://github.com/pytorch/examples/blob/master/word_language_model/data/wikitext-2/valid.txt&quot;,&quot;user_id&quot;:null}}"' b'[{&quot;id&quot;:' b'needs' b'btn-sm' b'aria-expanded="false"' b'd="M15' b'2.122a2.25' b'flex-md-items-center">' b'10.3' b'class="css-truncate' b'text:api">API</a></li>' b'</nav>' b'clearfix' b'0111.5' b'5.227A.25.25' b'<path' b'link-gray' b'Sign&nbsp;in' b'aria-label="Dismiss'
# b'data-src="https://github.githubassets.com/assets/chunk-drag-drop-a1b311f2.js"></script>' b'&quot;19741925936&quot;,' b'watching' b'src="https://github.githubassets.com/assets/diffs-e0679d65.js"></script>' b'3a1' b'<title>examples/train.txt' b'data-owner-scoped-search-url="/orgs/pytorch/search"' b'd-sm-inline">' b'&quot;trafficAllocation&quot;:' b'name="visitor-payload"' b'&quot;445&quot;}"' b'class="ml-3' b'src="https://avatars.githubusercontent.com/u/32325?s=48&amp;v=4"' b'[{&quot;id&quot;:' b'integrity="sha512-4GedZbTaNj0LwHjL3VP5orRBvkZbJ0aOLiI9wuClRDaZqq8VqKVL1iiAgnHmWLprmM9/1y40cmkEtlM2Txsk4w=="' b'Learning,' b'pb-4' b'data-content="Code">Code</span>' b'&quot;19739776731&quot;,' b'role="combobox"'
# b'border-0' b'6.25v-.878zm3.75' b'11.216.784' b'2.637-3.023a1.619' b'href="/pricing#feature-comparison"' b'navigation-item' b'flash-banner"' b'}}">' b'class="d-flex">' b'line"></summary>' b'.25zm0' b'aria-hidden="true">L</span>' b'&quot;en&quot;},' b'in,' b'Features">Features' b'[{&quot;id&quot;:' b'GitHub</title>' b'</button>' b'data-tab-item="i3actions-tab"' b'}}</span>'
# b'now.)</p>' b'data-content="Projects">Projects</span>' b'0H1.75zM1.5' b'href="/features"' b'class="d-lg-none' b'bg-blue' b'/></a>' b'<strong' b'data-hydro-click-hmac="ef93c2505f3805730378a168ba4cd6a5c4869e59513f8ab970098de8673b7e91"' b'data-src="https://github.githubassets.com/assets/chunk-contributions-spider-graph-7af7f2e9.js"></script>' b'Text,' b'octicon-play' b'4.458.75.75' b'}}/word_language_model/data/wikitext-2/train.txt"' b'style="background-color:' b'2.492' b'href="/pytorch">pytorch</a>' b'src="https://github.githubassets.com/assets/primer-21ba07f4.js"></script>' b'header-search-wrapper-jump-to' b'10.25v-7.5A1.75'
# b'<template' b'9.06l-3.22' b'&quot;click.empty_org_repo_cta.create_repository&quot;},' b'Trending">Trending' b'href="/login?return_to=%2Fpytorch%2Fexamples%2Fblob%2Fmaster%2Fword_language_model%2Fdata%2Fwikitext-2%2Ftrain.txt"' b'3.25zM11' b'000-1.5zm-2.25.75a2.25' b'1.715' b'GitHub' b'd="M7.177' b'8a8' b'd="M1.679' b'&quot;test_event.do_not_use_in_production&quot;},' b'0zM3.75' b'0011' b'&quot;variations&quot;:' b'top-0"' b'class="mr-2' b'data-hydro-click-hmac="304401ddf2b9a85258d35268f3b8f71de0c81bb3e5f0f9d54119b4b4cdac5d6b"' b'css-truncate-target">'
# b'<title>examples/test.txt' b'class="jump-to-octicon' b'5.5a.75.75' b'href="/nonprofit"' b'src="https://github.githubassets.com/assets/environment-f0adafbf.js"></script>' b'contrib' b'&quot;test_event.do_not_use_in_production&quot;},' b'from="0' b'property="og:site_name"' b'mb-n1"' b'href="/pytorch/examples/pulls">' b'&quot;18178755568&quot;,' b'out\\&quot;,\\&quot;originating_url\\&quot;:\\&quot;https://github.com/pytorch/examples/blob/master/word_language_model/data/wikitext-2/valid.txt\\&quot;,\\&quot;user_id\\&quot;:null}}&quot;,' b'data-hotkey="t">' b'subscription' b'd-block' b'01.216-.664l2.24-2.183-3.096-.45a.75.75' b'href="https://github.githubassets.com/assets/behaviors-210a99345b06c9006f872f88dce4945e.css"' b'class="Header-old' b'rel="search"'
# b'2.121' b'1.498-2.585' b'd-sm-inline"' b'</div>' b'octicon-trashcan"' b'style="min-height:' b'href="/pytorch/examples/commit/d5678bc8ac0cdd79dbd5e44d4130271018bcec4e">Replace' b'height="28">' b'hx_rsm-modal">' b'2.184a.75.75' b'4.78a.75.75' b'form-control"' b'name="optimizely-datafile"' b'position-fixed' b'd-none"' b'x="0px"' b'16' b'src="https://github.githubassets.com/images/search-key-slash.svg"' b'data-item-type="owner_scoped_search">' b'role="contentinfo">'
# b'class="d-lg-none' b'Security">Security' b'autocomplete="off"' b'Inc.</li>' b'hidden>You' b'name="viewport"' b'privacy,' b'lh-condensed-ultra' b'data-unscoped-search-url="/search"' b'content="https://api.github.com/_private/browser/stats">' b'pr-3' b'navigation"' b'11.5v-9zm10.5-1V9h-8c-.356' b'class="text-red' b'mr-0' b'in,' b'id="jump-to-results"' b'href="/pricing"' b'</h2>' b'{&quot;status&quot;:'
# b'&amp;' b'ml-3' b'correct' b'branches/tags"' b'16A8' b'accept="text/fragment+html"></include-fragment>' b'd="M1,1l6.2,6L13,1"></path>' b'6.78a.75.75' b'class="footer-octicon' b'progress-pjax-loader-bar' b'<img' b'style="box-sizing:' b'why?' b'aria-label="Search"' b'examples:master"' b'flex-md-order-2' b'1116' b'integrity="sha512-U+Pp1bYuA3fRqhike5Go//O/vsExaZLz00lrIby+rZ88yf03nQHz3wLZR9paWkakpD7TH5nS6AUpabCc7OFWpg=="' b'aria-label="Close' b'type="application/javascript"'
# b'js-details-container' b'data-module-id="./chunk-emoji-picker-element.js"' b'repo_deployments' b'href="/pytorch/examples/commits/master/word_language_model/data/wikitext-2/test.txt?author=adamlerer">' b'2.2.82.64-.18' b'flex-md-order-1' b'13.008' b'stroke="currentColor"' b'00-.174.238V7c0' b'text:status">Status</a></li>' b'}}/word_language_model/data/wikitext-2/test.txt"' b'}}"' b'data-unscoped-search-url="/search"' b'<eos>' b'1.06l-7.25' b'content="/&lt;user-name&gt;/&lt;repo-name&gt;/blob/show"' b'js-jump-to-owner-scoped-search' b'data-src="https://github.githubassets.com/assets/chunk-sortable-behavior-53e3e9d5.js"></script>' b'd-lg-inline-block"' b'href="/topics"'
# b'my-6' b'class="SelectMenu-tabs"' b'BtnGroup-item' b'line">' b'why?' b'content="https://api.github.com/_private/browser/optimizely_client/errors">' b'1.2' b'find' b'3.04a.75.75' b'clicked' b'7.002' b'break-word;">' b'1.75a.75.75' b'0v5.5a.75.75' b'href="/pricing"' b'Community' b'2.47a.75.75' b'href="/pytorch/examples/tree/master/word_language_model/data"><span>data</span></a></span><span' b'class="SelectMenu-filter">' b'href="/features/code-review/"'
# b'0zm-.25-5.25a.75.75' b'href="/sponsors"' b'HeaderMenu-link' b'href="/topics"' b'integrity="sha512-NwYkwzxETzKUYRXumHDsBIuggkh86KmJ1WrwWZW5wTvVPf047+wOmOHI5b4D65bfdtd3WbXJ7k+3ZWoxpIaqcA=="' b'correct' b'class="js-repo-root' b'homepage,' b'data-toggle-for="blob-more-options-details">' b'mb-md-0' b'10-1.06' b'class="SelectMenu-header">' b'1.06L2.06' b'00-7.9' b'5,' b'01.25.25v7.5a.25.25' b'<nav' b'href="/pytorch/examples/commit/d5678bc8ac0cdd79dbd5e44d4130271018bcec4e"' b'mb-0">' b'name="twitter:card"'
# b'Label--secondary' b'id="jump-to-results"' b'href="/pytorch/examples/tree/master/word_language_model/data/wikitext-2"><span>wikitext-2</span></a></span><span' b'00-1.06' b'&quot;19720506378&quot;,' b'style="width:24px;height:24px;"></div>' b'<span' b'content="width=device-width">' b'&quot;19969098350&quot;,' b'0v-7.5a.75.75' b'Bump-link--hover">Codespaces' b'mr-0' b'h5' b'type="hidden"' b'for' b'hx_rsm-modal">' b'src="https://avatars.githubusercontent.com/u/32325?s=48&amp;v=4"' b'name="enabled-features"' b'\xc2\xb7' b'master'
# b'11-1.06' b'8.566' b'3.75-3.65' b'p-responsive">' b'datetime="2017-12-05T08:42:15Z"' b'class="flex-auto">Go' b'3.427a.25.25' b'class=""' b'type="image/png"' b'role="tab"' b'2.47a.75.75' b'pt-lg-3">Connect' b'class="js-stale-session-flash' b'</nav>' b'GitHub</a></li>' b'</form>' b'octicon-history' b'class="issue-link' b'octicon-repo' b'id="raw-url"'
# b'4.21.612a.75.75' b'3.75-3.65' b'SelectMenu-icon' b'data-selected-links="' b'position-relative">' b'2.29' b'content="https://api.github.com/_private/browser/optimizely_client/errors">' b'1.429a.25.25' b'010-.354zM3.75' b'plans">Compare' b'href="/pytorch">pytorch</a>' b'href="/Smerity">Smerity</a>' b'css-truncate-target' b'content="">' b'>' b'GitHub</a></li>' b'2.717a.119.119' b'0c-2.447-1.042-4.049-2.357-5.032-3.855C1.32' b'repo_deployments' b'error">'
# b'lab">Learning' b'py-4' b'integrity="sha512-+N4rURJaQAH7alilIZ47KaP8sCRHB717YeeQnMh1WCZoxu1zUOlMcjRRobRIcBR1dcquwXOt/fkXNAud7u2eqw=="' b'class="position-relative">' b'dependabot_updates' b'class="author' b'show' b'Header,' b'wb-break-all"><a' b'111.06-1.06l3.04' b'href="https://github.com/site/terms">Terms</a></li>' b'autocapitalize="off"' b'js-jump-to-line-field"' b'content="pytorch/examples"' b'data-base-src="https://github.com/notifications/beta/shelf"></include-fragment>' b'href="/pytorch/examples/commit/d5678bc8ac0cdd79dbd5e44d4130271018bcec4e">Replace' b'0a8' b'data-hydro-click-hmac="a99afb43d77746d2a361fc04b98cf068b2fc918373dc6fba4ff9eadbf40cbd7d"' b'width-md-auto' b'flash-full'
# b'href="/pytorch/examples/commits/master/word_language_model/data/wikitext-2/test.txt?author=Smerity">' b'content="e633a4959e5a5315bb162b527b8a3fbb20d034cc2675aa8168069e6ade65c8f9"' b'v-align-text-bottom' b'<details' b'html>' b'overview' b'href=""' b'1116' b'octicon-check' b'type="tag"' b'tabindex="">' b'content="MARKETPLACE_PENDING_INSTALLATIONS,ACTIONS_SHORT_SHA_WARNING">' b'2.694v.001z"></path></svg>' b'11' b'01-.25-.25V1.75zM11.75' b'}}">{{' b'class="f6' b'href="/login?return_to=%2Fpytorch%2Fexamples%2Fblob%2Fmaster%2Fword_language_model%2Fdata%2Fwikitext-2%2Ftrain.txt"' b'Navigation' b'Navigation'
# b'href="/pytorch/examples/actions">' b'pb-0' b'mr-3"' b'v-align-text-bottom' b'href="/pytorch/examples/blob/master/word_language_model/data/wikitext-2/test.txt?raw=true">View' b'class="border-bottom' b'blob_contributors:v22:fd0ca701eec494b77e93bb8f69bb05e3875155738314be46f4ea2bba06bfbd3b' b'1.06L9.06' b'3.086' b'content="#1e2327">' b'0L1.698' b'repo_project' b'</button>' b'data-commit-hovercards-enabled' b'integrity="sha512-obMR8mPKx8OvqRe34LgnUcxeJ1qujiA4ND3H6UX13ExMlA/WfHLjEzXRmgGRcRvN/8J1nzc+Z+jgz/PLTFy6zg=="' b'&quot;hydro-click-hmac&quot;=&gt;&quot;f37bb8f498b07bb3f4441bac8eb3f665fe9a31891f0c02b988b9a0b74d5218df&quot;}' b'class="final-path">valid.txt</strong>' b'property="og:type"' b'menu&quot;,&quot;repository_id&quot;:null,&quot;auth_type&quot;:&quot;SIGN_UP&quot;,&quot;originating_url&quot;:&quot;https://github.com/pytorch/examples/blob/master/word_language_model/data/wikitext-2/valid.txt&quot;,&quot;user_id&quot;:null}}"' b'&quot;16822470375&quot;,'
# b'1.75a.25.25' b'0V5.372a2.25' b'<link' b'Customer' b'101.06' b'octicon-history' b'7.94' b'class="Skeleton' b'text-white"' b'px-2' b'class="SelectMenu-item"' b'&quot;submit.org_member_invitation.create&quot;},' b'01-.75.75h-4.5A.75.75' b'6.25v-.878zm3.75' b'href=""' b'.784' b'btn' b'Sponsors' b'top-0"' b'tabindex="">'
# b'Audience' b'integrity="sha512-tcH4xCRuMBAh1PruDaiwGnRIbHlF6bGLhxyCQ16uqok1cV5QFMguVPWJtN9KI0jGQOgN+Pha3+uOUXhXdfK/qw=="' b'go' b'text:Docs"' b'0v3.5a.75.75' b'3.086' b'name="hostname"' b'data-target="ref-selector.noMatchTemplate">' b'1zM9.018' b'octicon-shield' b'class="position-absolute' b'class="">' b'&quot;click.empty_org_repo_cta.transfer_repository&quot;},' b'&quot;19988571001&quot;,' b'&quot;18574203855&quot;,' b'flash' b'">Download</a>' b'hidden>' b'link-gray"' b'js-jump-to-octicon-project'
# b'00.4.2l1.45-1.087a.25.25' b'1.27.82' b'6.5' b'</h1>' b'8.72a.75.75' b'href="/pytorch/examples/raw/master/word_language_model/data/wikitext-2/valid.txt"' b'&quot;click.org_onboarding_checklist.invite_members&quot;},' b'octicon-x' b'01-.564-.41L8' b'href="/pytorch/examples/commits/master/word_language_model/data/wikitext-2/train.txt"' b'i"' b'src="https://avatars.githubusercontent.com/u/32325?s=48&amp;v=4"' b'class="Box-header' b'01.25.25v12.5a.25.25' b'&quot;variations&quot;:' b'1.279l-3.046' b'jump-to-suggestions' b'href="/pytorch/examples/issues">' b'role="img"><path' b'integrity="sha512-8K2vvwbW+6H27Nad5ydg8PA2/aMD/LKq+EiK9s0U0hhVZxCI2tWBsYk9beAtisRw2j+Or5k2/F+6dk02nmj/PA=="'
# b'content="false"' b'dataset' b'class="mr-2' b'dialog"' b'none;' b'flash-error"' b'00-.174.238V7c0' b'4.366-3.298C13.225' b'2.445L6.615' b'data-error-text="Failed' b'stroke-opacity="0.25"' b'mb-n1">' b'href="/pytorch/examples/watchers"' b'2px' b'id="js-flash-container">' b'name="user-login"' b'0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01' b'data-pjax-transient="true"/><meta' b'integrity="sha512-VJrqSK702Mzl9EQxm2OvFxKaumGptgVdeJS2rsaLvVlOdR4HEu3ZFjtV83kMKdYRelUnxxaAFw0wthkpdEUafw=="' b'&quot;anonymizeIP&quot;:'
# b'watch&quot;,&quot;repository_id&quot;:null,&quot;auth_type&quot;:&quot;LOG_IN&quot;,&quot;originating_url&quot;:&quot;https://github.com/pytorch/examples/blob/master/word_language_model/data/wikitext-2/test.txt&quot;,&quot;user_id&quot;:null}}"' b'title="Recent' b'type="tag"' b'101.6-5.684zM7.75' b'0V5.372A2.25' b'pulse' b'&quot;19720506378&quot;,' b'01-.564.41l-3.097.45' b'px-2"' b'content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc">' b'0a.75.75' b'&quot;19950395715&quot;,' b'\\&quot;custom_attribute\\&quot;,' b'text:sign-in">' b'data-hovercard-url="/users/Smerity/hovercard"' b'&quot;click.switch_account_context&quot;},' b'content="@github"' b'&quot;18591323364&quot;,' b'Compatibility&quot;}],' b'&quot;Running&quot;,'
# b'0L2.22' b'header-search-wrapper' b'00-1.06' b'class="js-stale-session-flash' b'class=""' b'action=""' b'class="link-gray"' b'id="context-commitish-filter-field"' b'Inc.</li>' b'navigation"' b'src="https://github.githubassets.com/assets/environment-f0adafbf.js"></script>' b'mr-3">' b'octicon-device-desktop"' b'class="d-inline"></include-fragment>' b'class="js-data-jump-to-suggestions-path-csrf"' b'1.124.967' b'repository' b'mb-3' b'1.06L9.06' b'be'
# b'0c-2.447-1.042-4.049-2.357-5.032-3.855C1.32' b'break-word;">' b'[{&quot;status&quot;:' b'Pricing,' b'00.4-.2v-3.25a.25.25' b'border-0">' b'hidden>You' b'details-reset' b'1.06l-7.25' b'6.423.43' b'defer="defer"' b'7h12.5a.75.75' b'aria-label="Open' b'aria-label="7241' b'jump-to-field' b'0C3.58' b'href="/pytorch/examples/blob/36441a83b6595524a538e342594ee6482754f374/word_language_model/data/wikitext-2/valid.txt">Permalink</a>' b'01-1.543-2.575L6.457' b'Watch' b'text:security"'
# b'class="inline-form"' b'src="/pytorch/examples/contributors/master/word_language_model/data/wikitext-2/valid.txt"' b'1.5.75.75' b'd="M3.72' b'Bump-link--hover">Code' b'mb-3' b'position-absolute' b'dialog"></summary>' b'</h1>' b'edge-item-fix' b'repository' b'flex-lg-justify-between' b'&quot;19741925936&quot;,' b'content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU">' b'branches/tags"' b'value="word_language_model/data/wikitext-2/test.txt"' b'{&quot;hydro-click&quot;=&gt;&quot;{\\&quot;event_type\\&quot;:\\&quot;analytics.click\\&quot;,\\&quot;payload\\&quot;:{\\&quot;category\\&quot;:\\&quot;Sign' b'js-navigation-container' b'data-hydro-click-hmac="01bc0ec37bcb13a52cf582a6fef459dfde7377ab0f6885dc0f91af4a52880561"' b'rel="nofollow"'
# b'py-2' b'0L1.698' b'set' b'content="github.com/pytorch/examples' b'pr-lg-5' b'octicon-device-desktop"' b'class="author' b'1.06L2.06' b'}}</div>' b'9a1.5' b'[{&quot;experimentIds&quot;:' b'stories' b'0v-5.5zM8' b'2.2.82.64-.18' b'show' b'master' b'<ul>' b'15.216.784' b'5.01' b'jump-to-suggestions-results-container'
# b'contribute</h4>' b'&quot;user_id&quot;},' b'011.06-1.06L6' b'<link' b'2.75v7.5C0' b'js-pjax-loader-bar' b'data-skip-pjax="true"' b'border-0">' b'href="https://github-cloud.s3.amazonaws.com">' b'data-hydro-click-hmac="a99afb43d77746d2a361fc04b98cf068b2fc918373dc6fba4ff9eadbf40cbd7d"' b'wb-break-all"><a' b'hx_rsm"' b'f4' b'border-0">' b'5.47a.75.75' b'Audience' b'16h6.5a.75.75' b'api,' b'account&quot;,&quot;label&quot;:&quot;ref_page:/&lt;user-name&gt;/&lt;repo-name&gt;/blob/show;ref_cta:Sign' b'loading">'
# b'octicon-repo' b'btn-with-count' b'flex-lg-row' b'0c2.245-.956' b'&quot;endOfRange&quot;:' b'action' b'tabindex=""' b'\\&quot;value\\&quot;:' b'js-jump-to-badge-jump">' b'&quot;19820830627&quot;,' b'&quot;click.contact_sales&quot;},' b'data-hydro-click-hmac="b396774c0b01a7f17f32addfe9ce1f003cbbbc4c8635fb83b6ac5f4531a0dc77"' b'data-module-id="./chunk-drag-drop.js"' b'css-truncate' b'before' b'class="flex-1' b'3a1' b'Pricing,' b'&quot;accountId&quot;:' b'f4'
# b'mb-5">' b'8a2' b'class="Box-header' b'hidden' b'tag"' b'header-search-key-slash">' b'2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95' b'load' b'js-navigation-open' b'mt-1' b'd="M5.72' b'class="UnderlineNav-body' b'border-lg-bottom-0' b'&quot;18564603625&quot;,' b'src="https://github.githubassets.com/assets/repositories-b3a1fcb3.js"></script>' b'&quot;19956217181&quot;,' b'1116' b'4.933-2.078' b'js-pjax-loader-bar' b'&quot;variations&quot;:'
# b'Bump-link--hover">Packages' b'class="SelectMenu-footer"><a' b'src="https://github.githubassets.com/assets/chunk-vendor-111977e2.js"></script>' b'<footer' b'new_repo_project' b'2.97.719' b'4a.75.75' b'pt-2' b'1.7' b'value=""' b'organization' b'data-src="https://github.githubassets.com/assets/chunk-drag-drop-a1b311f2.js"></script>' b'data-content="Security">Security</span>' b'Stars' b'Nonprofits">Nonprofit' b'JS' b'MB' b'mb-3' b'aria-label="More' b'1.68A1.75'
# b'<div>{{' b'"></span>' b'content="collector.githubapp.com"' b'00-1.5' b'integrity="sha512-8K2vvwbW+6H27Nad5ydg8PA2/aMD/LKq+EiK9s0U0hhVZxCI2tWBsYk9beAtisRw2j+Or5k2/F+6dk02nmj/PA=="' b'col-5' b'training,' b'&quot;click.classroom_create_classroom&quot;},' b'01-1.06' b'Bump-link--hover">Actions' b'id="tags-menu"' b'0v-3.5A.75.75' b'href="/login?return_to=%2Fpytorch%2Fexamples%2Fblob%2Fmaster%2Fword_language_model%2Fdata%2Fwikitext-2%2Ftrain.txt"' b'src="https://github.githubassets.com/assets/diffs-e0679d65.js"></script>' b'dropdown-menu-sw">' b'00-1.5' b'list-style-none' b'js-responsive-underlinenav-item"' b'aria-label="Homepage"' b'</button>'
# b'class="Box-btn-octicon' b'Explore' b'version="1.1"' b'0111.5' b'BtnGroup-item' b'class="d-flex">' b'<span>Latest' b'flash-full' b'mx-md-3' b'integrity="sha512-VJrqSK702Mzl9EQxm2OvFxKaumGptgVdeJS2rsaLvVlOdR4HEu3ZFjtV83kMKdYRelUnxxaAFw0wthkpdEUafw=="' b'5.784' b'vector-effect="non-scaling-stroke"' b'0v12.5c0' b'010' b'0zm-.25-5.25a.75.75' b'0zM6.379' b'class="logged-out' b'class="SelectMenu-title">Switch' b'&quot;click.org_onboarding_checklist.add_repo&quot;},' b'5.72'
# b'flex-auto">' b'min-width-0">' b'</html>' b'0zM8' b'text:status">Status</a></li>' b'\\&quot;exact\\&quot;,' b'aria-label="Homepage"' b'13.06l-5.22' b'position-fixed' b'href="/pytorch/examples/branches">View' b'mx-lg-4"' b'2.445L6.615' b'1.754a.25.25' b'399' b'data-scoped-placeholder="Search"' b'href="https://github.githubassets.com">' b'mt-2' b'1v1.128a2.251' b'flex-items-center"' b'd="M1,1l6.2,6L13,1"></path>'
# b'd="M13.78' b'header-logged-out' b'12a.75.75' b'py-2' b'fast"' b'class="text-mono' b'1.5z"></path></svg>' b'href="/customer-stories"' b'class="Popover' b'00-7-7"' b'0zM6.379' b'content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiI5NTNFOjBBREQ6RjU4N0FGOjEyMzAyNzg6NjAyRDkyMDUiLCJ2aXNpdG9yX2lkIjoiNDcxNjkyMzg4MTQxMjk4OTQ0NiIsInJlZ2lvbl9lZGdlIjoiaWFkIiwicmVnaW9uX3JlbmRlciI6ImlhZCJ9"' b'&quot;click.create_enterprise_trial&quot;}],' b'SelectMenu-icon' b'octicon-people' b'd-flex"' b'class="header-search' b'text:Pricing">Pricing</a></li>' b'mr-lg-0">&copy;' b'<html'
# b'content="https://api.github.com/_private/browser/errors">' b'signed' b'tooltipped-s' b'class="css-truncate-target"' b'itemscope' b'<path' b'color="#000000">' b'class="btn-octicon' b'line"></summary>' b'5.47' b'hidden' b'bg-gray' b'm-0' b'at' b'octicon-device-desktop"' b'Bump-link--hover">Codespaces' b'Collections">Collections' b'data-module-id="./chunk-user-status-submit.js"' b'101.5' b'data-pjax="#js-repo-pjax-container"'
# b'integrity="sha512-E+H+wAtjiqutBvn2cnXzDIvmasIhYiS7i7JzOfFUwo+Ej8zT54OrJtP//RhwixnypgOpCF4JvqzYy6zOtORDmg=="' b'&quot;[\\&quot;or\\&quot;,' b'&quot;16822470375&quot;,' b'data-ga-click="Repository,' b'text-gray-light' b'aria-expanded="false">' b'js-jump-to-suggestion"' b'text-gray-light"></span>' b'&quot;beginner_resources&quot;},' b'content="A' b'000-1.5zm-2.25.75a2.25' b'name="octolytics-host"' b'data-tab-item="i5security-tab"' b'class="d-lg-flex' b'progress-pjax-loader-bar' b'class="position-absolute' b'\xc2\xb7' b'default-branch="bWFzdGVy"' b'class="list-style-none' b'style="width:24px;height:24px;"></div>'
# b'1' b'type="rotate"' b'8.5h1.5v2.128a2.251' b'flex-md-self-auto' b'management' b'class="separator">/</span><span' b'js-jump-to-suggestions-container">' b'href="/pytorch">pytorch</a>' b'flex-self-stretch"' b'4.22a.75.75' b'else' b'href="/features/security"' b'&quot;hydro_click.dashboard.teacher_toolbox_cta&quot;},' b'menu&quot;,&quot;repository_id&quot;:null,&quot;auth_type&quot;:&quot;SIGN_UP&quot;,&quot;originating_url&quot;:&quot;https://github.com/pytorch/examples/blob/master/word_language_model/data/wikitext-2/valid.txt&quot;,&quot;user_id&quot;:null}}"' b'</div></details>' b'&quot;18210945499&quot;,' b'btn-with-count' b'width-md-auto' b'rel="canonical"' b'content="398772b6a6a1713167979366512bf7ebaa268a1e9094acec3fa3635463d98e68"'
# b'value="repo_source"' b'ml-n1' b'&quot;click.signup&quot;},' b'border-bottom' b'&quot;layerId&quot;:' b'aria-label="Global">' b'name="optimizely-datafile"' b'class="avatar' b'1.872-1.292' b'value="bT4JhzVenMBr4IqEN1dgzoLPX2UomiNmkDBWelh3Tj6OyydjSffu/mE/UU3FgWczaQxZ6FB8EGskJHYl18bhkQ=="' b'class="SelectMenu-modal">' b'flex-auto">' b'0v-2.5z"></path></svg>' b'1.566-.32' b'tooltipped-s' b'r="7"' b'src="/pytorch/examples/security/overall-count"' b'data-scope-type="Repository"' b'data-selected-links="repo_graphs' b'Education">Education'
# b'dialog"></summary>' b'type="button"' b'class="mt-0' b'href="https://github.com/site/privacy">Privacy</a></li>' b'loaded' b'1.87.87' b'&quot;19950395715&quot;,' b'<summary' b'list' b'14' b'data-module-id="./chunk-tweetsodium.js"' b'value="jFjJoT1SCdHHj4AckFFmejvyTQOGJL9MiXTU34aDg8Ndk09kLTsoWPL1FPpU01ZQIQOLWXjeehlYqfDE869hyA=="' b'class="js-notification-shelf-include-fragment"' b'hx_rsm"' b'6.53' b'but' b'd="M1.5' b'</button>' b'data-octo-dimensions="link_type:self"' b'<!--'
# b'&quot;19424193129&quot;,' b'011.5' b'Bump-link--hover">Code' b'integrity="sha512-E+H+wAtjiqutBvn2cnXzDIvmasIhYiS7i7JzOfFUwo+Ej8zT54OrJtP//RhwixnypgOpCF4JvqzYy6zOtORDmg=="' b'&quot;18195612788&quot;,' b'content="https://api.github.com/_private/browser/optimizely_client/errors">' b'mr-3' b'&quot;user_id&quot;},' b'12l5.22' b'accept-charset="UTF-8"' b'hx_underlinenav-item' b'text:Docs"' b'name="octolytics-dimension-repository_network_root_id"' b'class="container-xl' b'href="https://education.github.com"' b'10.25a.75.75' b'type="application/atom+xml">' b'ml-1' b'form-control"' b'border-lg-bottom-0'
# b'class="SelectMenu-title">Switch' b'href="/manifest.json"' b'container-xl' b'0-.694.074-1' b'class="' b'href="https://github.community"' b'up' b'text-center' b'data-hydro-click-hmac="bfec707c2d10253b38932a72c8e76632617f5c5ec13c462aa17131719af715fa"' b'input-entered:ref-selector#inputEntered' b'6.527' b'class="f6' b'aria-hidden="true">L</span>' b'js-navigation-open' b'&quot;click.view_account_billing_page&quot;},' b'<ul>' b'7.932c.412-.621' b'href="/join?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2F%3Cuser-name%3E%2F%3Crepo-name%3E%2Fblob%2Fshow&amp;source=header-repo"' b'<strong>History</strong>' b'env-production'
# b'[],' b'aria-hidden="true"><path' b'scoped-search' b'&quot;Running&quot;,' b'Bump-link--hover">Code' b'content="#1e2327">' b'signed' b'8.05' b'5.784' b'property="og:site_name"' b'0v-5.5zM8' b'octicon-x' b'1.07-.01' b'src="/pytorch/examples/commit/d5678bc8ac0cdd79dbd5e44d4130271018bcec4e/rollup?direction=e"' b'2.122a2.25' b'6.78a.75.75' b'no-underline' b'Sales' b'1.75a.25.25' b'2.122a2.25'
# b'tab-container-changed:input-demux#updateInput">' b'#79b8ff;width:' b'itemscope' b'mb-3">' b'rel="canonical"' b'1v1.128a2.251' b'data-hydro-click-hmac="01bc0ec37bcb13a52cf582a6fef459dfde7377ab0f6885dc0f91af4a52880561"' b'data-hydro-click-hmac="a99afb43d77746d2a361fc04b98cf068b2fc918373dc6fba4ff9eadbf40cbd7d"' b'class="position-absolute' b'4.001' b'name="browser-stats-url"' b'itemprop="name"' b'data-hydro-click-hmac="ef93c2505f3805730378a168ba4cd6a5c4869e59513f8ab970098de8673b7e91"' b'0v5.5a.75.75' b'lab">Learning' b'src="https://avatars.githubusercontent.com/u/32325?s=48&amp;v=4"' b'Issues' b'href="/pytorch/examples/actions">' b'7.59.4.07.55-.17.55-.38' b'dependabot_updates'
# b'stroke-linecap="round"' b'pt-6' b'&quot;hydro-click-hmac&quot;=&gt;&quot;01bc0ec37bcb13a52cf582a6fef459dfde7377ab0f6885dc0f91af4a52880561&quot;}' b'b"' b'sign' b'd-sm-inline"' b'<h3' b'href="/pytorch/examples/raw/master/word_language_model/data/wikitext-2/test.txt"' b'3.815' b'line&hellip;"' b'tab' b'd="M6.5' b'role="tab"' b'data-hydro-click="{&quot;event_type&quot;:&quot;authentication.click&quot;,&quot;payload&quot;:{&quot;location_in_page&quot;:&quot;repo' b'branches</a></footer>' b'js-site-search-field' b'&quot;click.compare_account_plans&quot;},' b'1.75' b'd-on-nav-focus' b'&quot;19950385587&quot;,'

# %% [markdown]
# GPT-2ではありませんが、モデルが言語の構造を学び始めていることが確認できます。
#
# これで動的量子化を解説する準備がほとんどできました。
# あとはいくつか補助的な関数を定義するだけです。

# %%
bptt = 25
criterion = nn.CrossEntropyLoss()
eval_batch_size = 1

# テストデータセットの作成
def batchify(data, bsz):
    # データセットをbsz個のパーツに綺麗に分割する方法を示します。
    nbatch = data.size(0) // bsz
    # うまく収まらない余分な要素を切り取ります。
    data = data.narrow(0, 0, nbatch * bsz)
    # bsz個のバッチ間でデータが均等になるように分割します。
    return data.view(bsz, -1).t().contiguous()

test_data = batchify(corpus.test, eval_batch_size)

# 評価関数
def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].reshape(-1)
    return data, target

def repackage_hidden(h):
  """隠れ層の状態を新しいテンソルにラップし、勾配の履歴から切り離します。"""

  if isinstance(h, torch.Tensor):
    return h.detach()
  else:
    return tuple(repackage_hidden(v) for v in h)

def evaluate(model_, data_source):
    # ドロップアウトを無効化する評価モードの有効化
    model_.eval()
    total_loss = 0.
    hidden = model_.init_hidden(eval_batch_size)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, bptt):
            data, targets = get_batch(data_source, i)
            output, hidden = model_(data, hidden)
            hidden = repackage_hidden(hidden)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
    return total_loss / (len(data_source) - 1)

# %% [markdown]
# ## 4. 動的量子化の検証
#
# 最後に`torch.quantization.quantize_dynamic`をモデルに呼び出します。
#
# そして、以下の2点を指定します。
# - モデル内の `nn.LSTM` モジュールと `nn.Linear` モジュールが量子化されるようにします。
# - 重みが`int8`の値に変換されるようにします。

# %%
import torch.quantization

quantized_model = torch.quantization.quantize_dynamic(
    model, {nn.LSTM, nn.Linear}, dtype=torch.qint8
)
print(quantized_model)
# Out:
# LSTMModel(
#   (drop): Dropout(p=0.5, inplace=False)
#   (encoder): Embedding(2363, 512)
#   (rnn): DynamicQuantizedLSTM(512, 256, num_layers=5, dropout=0.5)
#   (decoder): DynamicQuantizedLinear(in_features=256, out_features=2363, dtype=torch.qint8, qscheme=torch.per_tensor_affine)
# )

# %% [markdown]
# モデルは変わっていないように見えます。
# では、量子化はどのような利点をもたらしたのでしょうか。
#
# 一つは、モデルのサイズが大幅に削減されている点です。

# %%
def print_size_of_model(model):
    torch.save(model.state_dict(), "temp.p")
    print('Size (MB):', os.path.getsize("temp.p")/1e6)
    os.remove('temp.p')

print_size_of_model(model)
print_size_of_model(quantized_model)
# Out:
# Size (MB): 18.850932
# Size (MB): 8.38777

# %% [markdown]
# 二つ目は、評価用の損失に影響をほとんど与えることなく、推論時間を短縮している点です。
#
# 注釈：量子化モデルは単一スレッドで実行されるため、単一スレッドでの比較を行うためにスレッド数を1つにしています。

# %%
torch.set_num_threads(1)

def time_model_evaluation(model, test_data):
    s = time.time()
    loss = evaluate(model, test_data)
    elapsed = time.time() - s
    print('''loss: {0:.3f}\nelapsed time (seconds): {1:.1f}'''.format(loss, elapsed))

time_model_evaluation(model, test_data)
time_model_evaluation(quantized_model, test_data)
# Out:
# loss: 7.769
# elapsed time (seconds): 3.2
# loss: 7.769
# elapsed time (seconds): 1.7

# %% [markdown]
# 量子化せずにローカルのMacBook Pro上で上記コードを実行した場合、推論には200秒ほど掛かりますが、量子化を行うことで100秒ほどで推論を行えるようになります。

# %% [markdown]
# ## 結論
#
# 動的量子化は、モデルサイズを削減する上で最も簡単な方法であると考えられ、また量子化によって発生する精度への影響は限定的なものです。
#
# 本チュートリアルに目を通していただき、ありがとうございます。
# どんなフィードバックでも歓迎するので、もし何かございましたら、[こちら](https://github.com/pytorch/pytorch/issues)にissueを作成してください。（日本語訳注：日本語版チュートリアルに関連する内容であれば、是非[こちら](https://github.com/YutaroOgawa/pytorch_tutorials_jp)にissueの登録をお願いいたします。）
